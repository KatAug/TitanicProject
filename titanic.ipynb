# %% [markdown]
# Titanic Project

# %% [markdown]
# Setting up imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Creating Dataframe for Unclean CSV File

# %%
df = pd.read_csv("unclean_titanic_passenger_list.csv")

# %%
index_name=df.index.name
df.index.name = "Passenger #"
df.head()
# Out:
#              pclass  survived  \
# Passenger #
# 0                 1         1
# 1                 1         1
# 2                 1         0
# 3                 1         0
# 4                 1         0
#
#                                                         name     sex    age  \
# Passenger #
# 0                              Allen, Miss. Elisabeth Walton  female  29.00
# 1                             Allison, Master. Hudson Trevor    male   0.92
# 2                               Allison, Miss. Helen Loraine  female   2.00
# 3                       Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4            Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
#
#              sibsp  parch  ticket      fare    cabin embarked boat   body  \
# Passenger #
# 0                0      0   24160  211.3375       B5        S    2    NaN
# 1                1      2  113781  151.5500  C22 C26        S   11    NaN
# ...

# %% [markdown]
# Formatting/Renaming Column Values (Title Casing)

# %%
df["sex"] = df["sex"].str.title()
format_df = df.rename(columns={"pclass": "P_class", "survived": "Survived", "name": "Name", "sex": "Sex", "age": "Age","sibsp": "Sibling/Spouse", "parch": "Parent/Children", "ticket": "Ticket", "fare": "Fare", "cabin": "Cabin", "embarked": "Embarked", "boat": "Boat", "body": "Body", "home.dest": "Home_Dest"})
format_df.head()
# Out:
#              P_class  Survived  \
# Passenger #
# 0                  1         1
# 1                  1         1
# 2                  1         0
# 3                  1         0
# 4                  1         0
#
#                                                         Name     Sex    Age  \
# Passenger #
# 0                              Allen, Miss. Elisabeth Walton  Female  29.00
# 1                             Allison, Master. Hudson Trevor    Male   0.92
# 2                               Allison, Miss. Helen Loraine  Female   2.00
# 3                       Allison, Mr. Hudson Joshua Creighton    Male  30.00
# 4            Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female  25.00
#
#              Sibling/Spouse  Parent/Children  Ticket      Fare    Cabin  \
# Passenger #
# 0                         0                0   24160  211.3375       B5
# 1                         1                2  113781  151.5500  C22 C26
# ...

# %% [markdown]
# Checking For Null Values

# %%
format_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   P_class          1309 non-null   int64
#  1   Survived         1309 non-null   int64
#  2   Name             1309 non-null   object
#  3   Sex              1309 non-null   object
#  4   Age              1046 non-null   float64
#  5   Sibling/Spouse   1309 non-null   int64
#  6   Parent/Children  1309 non-null   int64
#  7   Ticket           1309 non-null   object
#  8   Fare             1308 non-null   float64
#  9   Cabin            295 non-null    object
#  10  Embarked         1307 non-null   object
#  11  Boat             486 non-null    object
#  12  Body             121 non-null    float64
#  13  Home_Dest        745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %% [markdown]
# Removing All Null Values

# %%
format_df.head()
# Out:
#              P_class  Survived  \
# Passenger #
# 0                  1         1
# 1                  1         1
# 2                  1         0
# 3                  1         0
# 4                  1         0
#
#                                                         Name     Sex    Age  \
# Passenger #
# 0                              Allen, Miss. Elisabeth Walton  Female  29.00
# 1                             Allison, Master. Hudson Trevor    Male   0.92
# 2                               Allison, Miss. Helen Loraine  Female   2.00
# 3                       Allison, Mr. Hudson Joshua Creighton    Male  30.00
# 4            Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female  25.00
#
#              Sibling/Spouse  Parent/Children  Ticket      Fare    Cabin  \
# Passenger #
# 0                         0                0   24160  211.3375       B5
# 1                         1                2  113781  151.5500  C22 C26
# ...

# %% [markdown]
# Change all "NaN" to 0's but only for columns Cabin, Boat, Body, and Home_Dest

# %%
#format_df.fillna(0, inplace=True)
#format_df.head()

# %% [markdown]
# Finding Outlier Values

# %%
sort_df = format_df.sort_values("Age")
sort_df.tail()
# Out:
#              P_class  Survived                               Name     Sex  \
# Passenger #
# 1293               3         0  Williams, Mr. Howard Hugh "Harry"    Male
# 1297               3         0             Wiseman, Mr. Phillippe    Male
# 1302               3         0                  Yousif, Mr. Wazli    Male
# 1303               3         0              Yousseff, Mr. Gerious    Male
# 1305               3         0              Zabour, Miss. Thamine  Female
#
#              Age  Sibling/Spouse  Parent/Children      Ticket     Fare Cabin  \
# Passenger #
# 1293         NaN               0                0    A/5 2466   8.0500   NaN
# 1297         NaN               0                0  A/4. 34244   7.2500   NaN
# 1302         NaN               0                0        2647   7.2250   NaN
# 1303         NaN               0                0        2627  14.4583   NaN
# 1305         NaN               1                0        2665  14.4542   NaN
#
# ...

# %% [markdown]
# Check for duplicates

# %%
sort_df.duplicated().sort_values()
# Out:
# Passenger #
# 763     False
# 788     False
# 68      False
# 148     False
# 30      False
#         ...
# 1024    False
# 370     False
# 635     False
# 517     False
# 1305    False
# Length: 1309, dtype: bool

# %% [markdown]
# Export to a CSV file

# %%
sort_df.to_csv("clean_titanic_passenger_list.csv",encoding="utf-8")
